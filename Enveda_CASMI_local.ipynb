# %% [markdown]
# # CASMI 2026 — Baseline Retrieval Pipeline

# %%
import sys
sys.path.insert(0, ".")

from src.data import load_sampled_train, load_test_set, make_validation_split
from src.baseline import build_submission
from src.metric import mrr_at_25

import pandas as pd

# %%
train_df = load_sampled_train(sample_size=75_000, random_state=42)
test_df = load_test_set()

print(f"Loaded {len(train_df):,} training spectra, {train_df['inchikey14'].nunique():,} unique structures")
print(f"Loaded {len(test_df):,} test spectra, {test_df['molecule_id'].nunique():,} unique molecules")
# Out:
# Loaded 75,000 training spectra, 52,730 unique structures
# Loaded 1,213 test spectra, 400 unique molecules

# %%
val_query_df, val_train_df, val_ground_truth = make_validation_split(
    train_df, n_held_out=200, random_state=42
)
print(f"Validation query set: {val_query_df['molecule_id'].nunique()} held-out molecules")
# Out:
# Validation query set: 200 held-out molecules

# %%
val_submission_df = build_submission(val_query_df, val_train_df, ppm_tolerance=15.0, top_k=25)
val_predictions = dict(
    zip(val_submission_df["molecule_id"], val_submission_df["smiles"].str.split(";"))
)

offline_mrr25 = mrr_at_25(val_predictions, val_ground_truth)
print(f"Offline MRR@25 (spectrum-level held-out split, timsTOF-preferred): {offline_mrr25:.4f}")
# Out:
# 2026-09-24 01:05:58,793:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:05:58,793:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,461:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,462:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,462:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,463:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,467:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,468:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,469:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,469:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,478:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,479:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,480:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,480:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,481:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,482:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,483:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,484:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,484:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,485:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,487:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,488:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,489:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,489:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,489:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,491:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,525:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,525:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,526:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,528:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,528:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,529:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,530:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,530:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,532:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,532:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,533:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,534:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,535:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,536:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,536:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,537:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,538:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,542:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,543:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,545:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,547:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,547:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,548:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,552:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,553:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,553:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,562:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,563:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,563:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,564:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,565:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,565:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,566:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,567:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,568:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,568:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,569:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,569:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,571:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,571:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,572:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,573:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,573:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,574:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,574:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,575:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,576:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,577:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,578:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,579:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,579:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,584:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,585:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,585:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,586:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,587:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,588:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,590:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,590:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,591:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,592:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,592:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,593:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,595:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,596:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,596:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,597:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,610:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,610:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,615:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,617:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,625:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,626:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,634:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,634:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,639:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,640:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,641:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,642:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,648:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,648:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,649:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,654:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,655:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,656:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,657:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,665:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,666:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,671:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,671:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,672:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,674:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,679:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,681:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,681:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,682:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,683:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,684:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,685:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,686:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,686:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,688:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,688:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,689:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,690:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,690:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,691:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,691:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,691:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,694:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,695:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,696:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,697:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,698:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,699:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,700:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,701:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,701:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,702:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,703:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,704:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,704:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,709:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,710:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,719:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,720:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,720:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,721:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,729:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,729:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,730:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,738:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,738:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,745:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,772:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,772:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,772:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,772:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,783:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,795:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,814:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,815:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,815:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,815:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,817:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,818:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,822:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,823:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,824:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,824:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,825:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,825:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,830:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,831:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,831:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,832:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,832:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,837:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,837:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,838:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,838:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,843:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,844:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,876:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,891:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,891:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,892:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,892:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,892:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:02,892:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,359:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,359:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,375:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,378:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,406:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,438:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,438:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,445:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,445:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,445:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,445:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,451:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,454:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,455:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,456:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,456:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,462:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,463:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,463:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,471:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,471:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,473:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,473:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,473:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,479:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,480:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,481:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,481:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,482:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,483:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,490:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,491:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,506:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,508:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,508:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,527:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,527:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,533:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,533:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,534:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,535:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,536:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,537:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,538:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,542:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,543:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,549:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,554:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,555:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,555:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,556:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,558:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,560:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:03,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# ...
# 2026-09-24 01:06:06,978:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,978:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,978:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,981:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,983:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:06,994:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,003:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,003:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,003:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,003:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,003:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,016:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,017:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,025:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,027:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,028:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,029:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,031:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,032:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,032:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,035:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,035:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,036:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,040:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,040:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,047:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,047:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,047:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,096:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,096:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,101:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,101:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,101:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,101:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,107:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,109:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,109:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,110:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,115:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,115:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,115:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,116:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,121:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,121:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,121:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,121:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,128:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,133:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,133:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,134:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,135:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,135:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,135:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,137:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,142:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,143:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,143:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:07,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# [01:06:07] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:06:07] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:06:07] Invalid InChI prefix in generating InChI Key
# [01:06:07] Invalid InChI prefix in generating InChI Key
# [01:06:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:07] Invalid InChI prefix in generating InChI Key
# [01:06:07] Invalid InChI prefix in generating InChI Key
# [01:06:08] Invalid InChI prefix in generating InChI Key
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 4 23
# [01:06:08] Invalid InChI prefix in generating InChI Key
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:08] Can't kekulize mol.  Unkekulized atoms: 3 4 11 22
# [01:06:09] Invalid InChI prefix in generating InChI Key
# [01:06:09] Invalid InChI prefix in generating InChI Key
# [01:06:10] Invalid InChI prefix in generating InChI Key
# [01:06:10] Invalid InChI prefix in generating InChI Key
# [01:06:10] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:10] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:10] Invalid InChI prefix in generating InChI Key
# [01:06:11] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:11] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:06:11] Can't kekulize mol.  Unkekulized atoms: 2 6
# Offline MRR@25 (spectrum-level held-out split, timsTOF-preferred): 0.4173
# [01:06:13] Invalid InChI prefix in generating InChI Key

# %%
submission_df = build_submission(test_df, train_df, ppm_tolerance=15.0, top_k=25)

# Kaggle format constraints: no empty/NaN smiles allowed. Fall back to a
# placeholder for molecules with zero candidates so the file stays valid.
submission_df["smiles"] = submission_df["smiles"].replace("", "CCO")

assert submission_df["molecule_id"].is_unique
assert submission_df["smiles"].notna().all()
assert (submission_df["smiles"].str.count(";") <= 24).all()

submission_df.to_csv("submission.csv", index=False)
print(f"Wrote submission.csv with {len(submission_df)} rows")
submission_df.head()
# Out:
# 2026-09-24 01:06:13,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,145:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,146:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,146:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,147:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,152:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,152:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,153:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,154:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,154:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,155:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,160:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,161:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,161:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,162:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,163:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,163:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,172:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,172:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,173:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,175:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,178:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,178:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,193:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,208:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,212:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,212:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,213:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,224:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,225:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,227:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,227:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,227:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,229:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,257:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,257:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,257:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,257:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,257:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,260:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,261:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,261:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,262:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,262:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,263:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,264:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,265:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,270:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,270:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,271:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,272:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,273:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,273:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,274:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,275:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,275:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,277:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,277:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,278:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,279:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,280:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,280:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,281:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,282:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,286:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,287:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,287:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,288:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,289:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,289:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,290:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,291:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,291:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,292:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,293:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,293:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,294:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,294:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,294:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,296:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,297:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,342:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,342:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,357:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,361:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,361:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,362:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,366:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,367:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,367:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,368:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,368:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,369:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,370:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,370:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,371:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,372:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,372:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,373:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,374:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,374:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,375:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,376:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,377:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,379:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,379:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,380:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,380:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,381:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,382:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,383:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,384:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,385:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,386:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,387:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,388:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,392:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,393:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,395:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,396:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,397:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,400:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,403:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,403:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,403:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,410:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,411:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,411:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,412:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,413:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,413:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,414:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,415:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,416:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,417:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,417:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,418:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,419:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,420:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,420:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,421:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,423:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,424:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,424:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,425:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,426:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,427:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,427:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,428:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,429:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,430:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,430:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,432:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,432:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,434:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,436:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,436:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,441:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,442:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,443:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,443:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,474:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,497:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,497:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,502:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,502:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,503:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,503:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,504:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,504:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,504:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,506:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,506:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,522:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,523:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,523:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,529:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,529:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,530:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,532:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,537:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,538:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,549:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,549:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,586:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,586:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,587:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,587:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,598:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,599:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,600:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,600:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,601:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,602:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,602:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,603:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,604:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,604:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,605:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,606:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,607:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,608:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,608:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,609:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,609:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,610:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,610:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,611:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,611:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,617:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,617:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,618:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,618:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,619:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,620:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,624:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,625:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,626:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,639:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,639:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,639:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,644:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,657:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,657:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,657:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:13,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# ...
# 2026-09-24 01:06:31,025:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,053:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,098:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,098:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,098:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,104:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,104:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,104:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,112:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,112:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,113:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,117:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,118:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,119:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,124:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,128:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,131:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,131:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,136:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,137:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,140:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,141:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,141:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,142:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,143:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,143:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,160:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,160:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,160:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,166:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,166:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,166:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,172:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,172:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,174:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,204:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,205:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,205:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,205:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,205:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,208:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,208:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,208:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,208:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2026-09-24 01:06:31,211:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Wrote submission.csv with 400 rows
#   molecule_id                                             smiles
# 0    m_005e53  COCc1nc2n(n1)CCCC2NS(=O)(=O)c1c(F)cccc1Cl;Cc1n...
# 1    m_006153  CC(=O)Nc1ccc(C(=O)CSc2ccc(C(C)(C)C)cc2)cc1;CN1...
# 2    m_00b5aa  COc1ccnc(CN2CCOCC3(CCCC3)C2)c1OC;COCC1CCN(C(=O...
# 3    m_01e922  CC(C)C(C)C(=O)NCc1cccc(C(=O)O)c1;OC1CCC(NCc2cc...
# 4    m_0259d4  Cc1n[nH]c(C)c1NC(=O)CN1CCC2(C1)C(=O)Nc1ccccc12...

# %% [markdown]
# ## AutoGluon Reranker (sub-project 2)
#
# Trains a binary-classification tree ensemble on richer per-candidate
# features (cosine score, mass accuracy, RDKit descriptors) to reorder
# the baseline's candidates. Compares offline MRR@25 before/after
# reranking on the same held-out split.
#
# **Note:** this section requires the `.venv-reranker` environment
# (Python 3.12 + autogluon.tabular) — run this notebook's kernel from
# that venv, not the system Python 3.14 kernel used for the baseline
# cells above (AutoGluon has no Python 3.14 support as of this writing).

# %%
import matchms
matchms.set_matchms_logger_level("ERROR")  # suppress verbose "No precursor_mz found" WARNING spam

from src.reranker import (
    build_training_examples,
    train_reranker,
    extract_candidate_features,
    rerank_candidates,
)

_RERANKER_FEATURE_COLUMNS = [
    "cosine_score", "ppm_error", "num_peaks_candidate",
    "mol_wt", "log_p", "num_rings", "num_rotatable_bonds", "num_hbd", "num_hba",
]

# %%
reranker_training_df = build_training_examples(
    train_df, n_held_out=200, random_state=42
)
print(f"Reranker training examples: {len(reranker_training_df)} rows, "
      f"{reranker_training_df['is_correct'].sum()} positive")

reranker_predictor = train_reranker(
    reranker_training_df,
    model_path="./autogluon_reranker_model",
    feature_columns=_RERANKER_FEATURE_COLUMNS,
    time_limit=120,
)
# Out:
# Reranker training examples: 1882 rows, 91 positive
# Verbosity: 2 (Standard Logging)
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# =================== System Info ===================
# AutoGluon Version:  1.6.3
# Python Version:     3.12.10
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26200
# CPU Count:          16
# Pytorch Version:    Can't import torch
# CUDA Version:       Can't get cuda version from torch
# Memory Avail:       2.57 GB / 15.69 GB (16.4%)
# Disk Space Avail:   292.92 GB / 644.23 GB (45.5%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme'  : Use this if you have a GPU. The go-to preset for best results, and the one to use for benchmark comparisons. New in v1.6: far better than 'best' on datasets <100000 samples by using Tabular Foundation Models (TFMs) meta-learned on https://tabarena.ai: Nori, TabICLv2, and TabDPT-Turbo. Every model is free for commercial use. Requires `pip install autogluon.tabular[tabarena]`.
# 	presets='noncommercial': New in v1.6: 'extreme' plus TabPFN-3, a frontier tabular foundation model created by Prior Labs. Stronger still, but commercial use requires a TabPFN-3 license: https://docs.priorlabs.ai/models#tabpfn-model-license
# 	presets='best'     : Use this if you do not have a GPU. Maximize accuracy. Use in competitions.
# 	presets='best_v150': New in v1.5: Better quality than 'best' and 5x+ faster to train. Give it a try!
# 	presets='high'     : Strong accuracy with fast inference speed.
# 	presets='high_v150': New in v1.5: Better quality than 'high' and 5x+ faster to train. Give it a try!
# 	presets='good'     : Good accuracy with very fast inference speed.
# 	presets='medium'   : Fast training time, ideal for initial prototyping.
# Using hyperparameters preset: hyperparameters='default'
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "C:\Users\novan\Desktop\Projects\Enveda CASMI 2026 - Molecule ID From Mass Spectra\autogluon_reranker_model"
# Train Data Rows:    1882
# Train Data Columns: 9
# Label Column:       is_correct
# Problem Type:       binary
# Preprocessing data...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2496.37 MB
# 	Train Data (Original)  Memory Usage: 0.13 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 4 | ['cosine_score', 'ppm_error', 'mol_wt', 'log_p']
# 		('int', [])   : 5 | ['num_peaks_candidate', 'num_rings', 'num_rotatable_bonds', 'num_hbd', 'num_hba']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 4 | ['cosine_score', 'ppm_error', 'mol_wt', 'log_p']
# 		('int', [])   : 5 | ['num_peaks_candidate', 'num_rings', 'num_rotatable_bonds', 'num_hbd', 'num_hba']
# 	0.0s = Fit runtime
# 	9 features in original data used to generate 9 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.13 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.03s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1505, Val Rows: 377
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 11 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ... Training model for up to 119.97s of the 119.97s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0, mem=0.1/2.4 GB
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. A quick tip is to install via `pip install autogluon.tabular[lightgbm]==1.6.3`.
# Fitting model: LightGBM ... Training model for up to 119.78s of the 119.78s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0, mem=0.1/2.4 GB
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. A quick tip is to install via `pip install autogluon.tabular[lightgbm]==1.6.3`.
# Fitting model: RandomForestGini ... Training model for up to 119.66s of the 119.66s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=16, gpus=0
# 	0.9889	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 118.63s of the 118.63s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=16, gpus=0
# 	0.9926	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 118.02s of the 118.02s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0
# 	Warning: Exception caused CatBoost to fail during training (ImportError)... Skipping this model.
# 		`import catboost` failed. A quick tip is to install via `pip install autogluon.tabular[catboost]==1.6.3`.
# Fitting model: ExtraTreesGini ... Training model for up to 117.89s of the 117.89s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=16, gpus=0
# 	0.9926	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 117.27s of the 117.27s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=16, gpus=0
# 	0.9928	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 116.66s of the 116.66s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0, mem=0.0/2.3 GB
# 	Warning: Exception caused NeuralNetFastAI to fail during training (ImportError)... Skipping this model.
# 		Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.6.3`.
# Fitting model: XGBoost ... Training model for up to 116.54s of the 116.54s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0
# 	Warning: Exception caused XGBoost to fail during training (ImportError)... Skipping this model.
# 		`import xgboost` failed. A quick tip is to install via `pip install autogluon.tabular[xgboost]==1.6.3`.
# Fitting model: NeuralNetTorch ... Training model for up to 116.39s of the 116.39s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0, mem=0.0/2.3 GB
# 	Warning: Exception caused NeuralNetTorch to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency torch
# A quick tip is to install via `pip install torch`.
# The minimum torch version is currently 2.10.
# Fitting model: LightGBMLarge ... Training model for up to 116.26s of the 116.26s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting with cpus=12, gpus=0, mem=0.1/2.3 GB
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. A quick tip is to install via `pip install autogluon.tabular[lightgbm]==1.6.3`.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.97s of the 116.05s of remaining time.
# 	Failed to import torch or check CUDA availability!Please ensure you have the correct version of PyTorch installed by running `pip install -U torch`
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=0, mem=0.0/2.2 GB
# 	Ensemble Weights: {'RandomForestEntr': 0.667, 'ExtraTreesEntr': 0.333}
# 	0.9937	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4.11s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 3800.4 rows/s (377 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Users\novan\Desktop\Projects\Enveda CASMI 2026 - Molecule ID From Mass Spectra\autogluon_reranker_model")

# %% [markdown]
# ### Independent evaluation split (double-holdout)
#
# The reranker's training data (above) uses `make_validation_split(..., random_state=42)`. Scoring baseline-vs-reranked MRR@25 on that same split would be in-sample — the model has already seen those rows during training. This cell draws a SEPARATE held-out split with a different `random_state` so the comparison below reflects genuine generalization, not memorization.

# %%
eval_query_df, eval_train_df, eval_ground_truth = make_validation_split(
    train_df, n_held_out=200, random_state=99
)
print(f"Independent eval set: {eval_query_df['molecule_id'].nunique()} held-out molecules "
      f"(disjoint random_state from reranker training split)")
# Out:
# Independent eval set: 200 held-out molecules (disjoint random_state from reranker training split)

# %%
baseline_predictions_cmp = {}
reranked_predictions_cmp = {}

for molecule_id, group in eval_query_df.groupby("molecule_id"):
    features = extract_candidate_features(group, eval_train_df, ppm_tolerance=15.0)
    if features.empty:
        baseline_predictions_cmp[molecule_id] = [""]
        reranked_predictions_cmp[molecule_id] = [""]
        continue
    baseline_order = features.sort_values("cosine_score", ascending=False)["smiles"].tolist()
    baseline_predictions_cmp[molecule_id] = baseline_order if baseline_order else [""]
    reranked_predictions_cmp[molecule_id] = rerank_candidates(
        reranker_predictor, features, _RERANKER_FEATURE_COLUMNS, top_k=25
    ) or [""]

baseline_mrr_cmp = mrr_at_25(baseline_predictions_cmp, eval_ground_truth)
reranked_mrr_cmp = mrr_at_25(reranked_predictions_cmp, eval_ground_truth)

print(f"Baseline-only MRR@25:  {baseline_mrr_cmp:.4f}")
print(f"Reranked MRR@25:       {reranked_mrr_cmp:.4f}")
print(f"Delta:                 {reranked_mrr_cmp - baseline_mrr_cmp:+.4f}")
print()
print("Independent double-holdout: this eval split (random_state=99) is disjoint "
      "from the reranker's training split (random_state=42), so this delta reflects "
      "genuine generalization rather than in-sample memorization.")
# Out:
# [01:07:05] Invalid InChI prefix in generating InChI Key
# [01:07:05] Invalid InChI prefix in generating InChI Key
# [01:07:05] Invalid InChI prefix in generating InChI Key
# [01:07:05] Can't kekulize mol.  Unkekulized atoms: 3 13
# [01:07:05] Can't kekulize mol.  Unkekulized atoms: 3 13
# [01:07:06] Invalid InChI prefix in generating InChI Key
# [01:07:06] Invalid InChI prefix in generating InChI Key
# [01:07:06] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:06] Invalid InChI prefix in generating InChI Key
# [01:07:07] Invalid InChI prefix in generating InChI Key
# [01:07:07] Invalid InChI prefix in generating InChI Key
# [01:07:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:07] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:07] Invalid InChI prefix in generating InChI Key
# [01:07:08] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:08] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:08] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:08] Invalid InChI prefix in generating InChI Key
# [01:07:08] Can't kekulize mol.  Unkekulized atoms: 3 20
# [01:07:09] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:07:09] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:07:09] Can't kekulize mol.  Unkekulized atoms: 4 23
# [01:07:09] Invalid InChI prefix in generating InChI Key
# [01:07:09] Invalid InChI prefix in generating InChI Key
# [01:07:09] Invalid InChI prefix in generating InChI Key
# [01:07:09] Can't kekulize mol.  Unkekulized atoms: 5 22
# [01:07:10] Invalid InChI prefix in generating InChI Key
# [01:07:10] Invalid InChI prefix in generating InChI Key
# [01:07:10] Invalid InChI prefix in generating InChI Key
# [01:07:11] Can't kekulize mol.  Unkekulized atoms: 3 13
# [01:07:11] Can't kekulize mol.  Unkekulized atoms: 3 13
# [01:07:11] Invalid InChI prefix in generating InChI Key
# [01:07:11] Invalid InChI prefix in generating InChI Key
# [01:07:11] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:11] Invalid InChI prefix in generating InChI Key
# [01:07:12] Invalid InChI prefix in generating InChI Key
# [01:07:12] Invalid InChI prefix in generating InChI Key
# [01:07:12] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:12] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:12] Can't kekulize mol.  Unkekulized atoms: 2 6
# [01:07:12] Invalid InChI prefix in generating InChI Key
# [01:07:13] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:13] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:13] Can't kekulize mol.  Unkekulized atoms: 3 7
# [01:07:13] Invalid InChI prefix in generating InChI Key
# [01:07:13] Can't kekulize mol.  Unkekulized atoms: 3 20
# [01:07:14] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:07:14] Can't kekulize mol.  Unkekulized atoms: 1 5
# [01:07:14] Can't kekulize mol.  Unkekulized atoms: 4 23
# [01:07:14] Invalid InChI prefix in generating InChI Key
# Baseline-only MRR@25:  0.3849
# Reranked MRR@25:       0.3946
# Delta:                 +0.0097
#
# Independent double-holdout: this eval split (random_state=99) is disjoint from the reranker's training split (random_state=42), so this delta reflects genuine generalization rather than in-sample memorization.
# [01:07:14] Invalid InChI prefix in generating InChI Key
# [01:07:14] Invalid InChI prefix in generating InChI Key
